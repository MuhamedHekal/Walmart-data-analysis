# %%
# %pip install oracledb
# Out:
# Requirement already satisfied: oracledb in /opt/anaconda3/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: cryptography>=3.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from oracledb) (42.0.5)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.12/site-packages (from cryptography>=3.2.1->oracledb) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
suppliers_dim_insert = '''insert into suppliers_dim (SupplierID, SupplierName, ContactName, Phone, Email, Address) values(:1, :2, :3, :4,:5, :6)'''
suppliers_dim_select = "select SupplierID, SupplierName, ContactName, Phone, Email, Address from suppliers"

# %%
import oracledb
import pandas as pd

# Connect to the Oracle database
operational_connection = oracledb.connect(user="walmart", password="walmart", dsn="127.0.0.1:1521/freepdb1")
print("Connected to Oracle Database")
 
# Create a cursor to execute queries
operational_cursor = operational_connection.cursor()
def get_data_frame(cursor, query):
    # Execute the SQL query
    cursor.execute(query)
    # Fetch all rows from the query result
    data = cursor.fetchall()
    # Get column names (metadata)
    columns = [desc[0] for desc in cursor.description]
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data, columns=columns)
    return df
# Out:
# Connected to Oracle Database

# %%
suppliers_df = get_data_frame(operational_cursor, suppliers_dim_select)
suppliers_df
# Out:
#     SUPPLIERID                SUPPLIERNAME        CONTACTNAME         PHONE  \
# 0            1   Beverage Distributors Co.         John Smith  123-456-7890
# 1            2      Global Condiments Ltd.      Sarah Johnson  234-567-8901
# 2            3           Sweet Treats Inc.        Emily Davis  345-678-9012
# 3            4             Dairy Farms LLC      Michael Brown  456-789-0123
# 4            5        Grain Supplies Corp.       Laura Wilson  567-890-1234
# 5            6             Fresh Meats Co.     David Martinez  678-901-2345
# 6            7         Organic Produce LLC     Jessica Garcia  789-012-3456
# 7            8            Ocean Catch Inc.         Daniel Lee  890-123-4567
# 8            9              Snack Time Co.       Karen Taylor  901-234-5678
# 9           10        Frozen Delights Ltd.    Andrew Robinson  012-345-6789
# 10          11        Baking Supplies Inc.       Sophia Clark  123-456-7890
# 11          12  Personal Care Products Co.          Ryan Hall  234-567-8901
# 12          13   Household Essentials Ltd.        Megan Allen  345-678-9012
# 13          14         Pet Lovers Supplies      Joshua Wright  456-789-0123
# 14          15     Health and Wellness Co.       Natalie King  567-890-1234
# 15          16          Baby Care Supplies       Samuel Scott  678-901-2345
# 16          17        Organic Farmers Ltd.     Victoria Adams  789-012-3456
# 17          18       Drink Mix Specialists     Benjamin Lopez  890-123-4567
# 18          19    International Foods Inc.        Hannah Hill  901-234-5678
# 19          20            Canned Goods Co.  Christopher Green  012-345-6789
#
#                                   EMAIL  \
# 0           john.smith@beveragedist.com
# 1    sarah.johnson@globalcondiments.com
# 2           emily.davis@sweettreats.com
# 3          michael.brown@dairyfarms.com
# 4        laura.wilson@grainsupplies.com
# 5         david.martinez@freshmeats.com
# 6     jessica.garcia@organicproduce.com
# 7             daniel.lee@oceancatch.com
# 8            karen.taylor@snacktime.com
# 9    andrew.robinson@frozendelights.com
# 10      sophia.clark@bakingsupplies.com
# 11           ryan.hall@personalcare.com
# 12  megan.allen@householdessentials.com
# 13          joshua.wright@petlovers.com
# 14   natalie.king@healthandwellness.com
# 15    samuel.scott@babycaresupplies.com
# 16    victoria.adams@organicfarmers.com
# 17          benjamin.lopez@drinkmix.com
# 18            hannah.hill@intlfoods.com
# 19    christopher.green@cannedgoods.com
#
#                                         ADDRESS
# 0          123 Beverage Lane, New York, NY, USA
# 1        456 Condiment Street, Chicago, IL, USA
# 2   789 Confection Road, San Francisco, CA, USA
# 3            101 Dairy Avenue, Madison, WI, USA
# 4           202 Grain Boulevard, Omaha, NE, USA
# 5              303 Meat Street, Dallas, TX, USA
# 6          404 Produce Avenue, Seattle, WA, USA
# 7              505 Seafood Lane, Miami, FL, USA
# 8               606 Snack Road, Denver, CO, USA
# 9               707 Frozen Way, Boston, MA, USA
# 10           808 Baking Lane, Portland, OR, USA
# 11             909 Care Street, Austin, TX, USA
# 12          1010 Supply Drive, Phoenix, AZ, USA
# 13             111 Pet Lane, San Diego, CA, USA
# 14   222 Wellness Road, Salt Lake City, UT, USA
# 15         333 Baby Drive, Minneapolis, MN, USA
# 16           444 Organic Road, Atlanta, GA, USA
# 17               555 Mix Lane, Detroit, MI, USA
# 18         666 Cuisine Street, Houston, TX, USA
# 19               777 Can Road, Memphis, TN, USA

# %%
# Connect to the Oracle database
star_connection = oracledb.connect(user="walmart_star_schema", password="walmart", dsn="127.0.0.1:1521/freepdb1")
star_cursor = star_connection.cursor()
print("Connected to Oracle Database")
def insert_data_frame(cursor, query, dataFrame):
    for i, row in dataFrame.iterrows():
        cursor.execute(query, tuple(row))
    cursor.execute('commit')
# Out:
# Connected to Oracle Database

# %%
insert_data_frame(star_cursor, suppliers_dim_insert ,suppliers_df)

# %%
# %pip install oracledb
# Out:
# Requirement already satisfied: oracledb in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.5.1)
# Requirement already satisfied: cryptography>=3.2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from oracledb) (44.0.0)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cryptography>=3.2.1->oracledb) (1.17.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=3.2.1->oracledb) (2.22)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
category_dim_insert = '''insert into category_dim (CategoryID, CategoryNAME, Description) values(:1, :2, :3)'''

# %%
import oracledb
import pandas as pd

# Connect to the Oracle database
operational_connection = oracledb.connect(user="walmart", password="walmart", dsn="127.0.0.1:1521/freepdb1")
print("Connected to Oracle Database")
 
# Create a cursor to execute queries
operational_cursor = operational_connection.cursor()
def get_data_frame(cursor, query):
    # Execute the SQL query
    cursor.execute(query)
    # Fetch all rows from the query result
    data = cursor.fetchall()
    # Get column names (metadata)
    columns = [desc[0] for desc in cursor.description]
    # Convert the data into a pandas DataFrame
    df = pd.DataFrame(data, columns=columns)
    return df
# Out:
# Connected to Oracle Database

# %%
category_df = get_data_frame(operational_cursor, "select CategoryID, CategoryNAME, Description  from Categories")
# Connect to the Oracle database
star_connection = oracledb.connect(user="walmart_star_schema", password="walmart", dsn="127.0.0.1:1521/freepdb1")
star_cursor = star_connection.cursor()
print("Connected to Oracle Database")
def insert_data_frame(cursor, query, dataFrame):
    for i, row in dataFrame.iterrows():
        cursor.execute(query, tuple(row))
    cursor.execute('commit')
# Out:
# Connected to Oracle Database

# %%
insert_data_frame(star_cursor, category_dim_insert ,category_df)

# %%
category_df
# Out:
#     CATEGORYID          CATEGORYNAME  \
# 0            1             Beverages
# 1            2            Condiments
# 2            3           Confections
# 3            4        Dairy Products
# 4            5        Grains Cereals
# 5            6          Meat Poultry
# 6            7               Produce
# 7            8               Seafood
# 8            9                Snacks
# 9           10          Frozen Foods
# 10          11          Baking Goods
# 11          12         Personal Care
# 12          13    Household Supplies
# 13          14          Pet Supplies
# 14          15   Health and Wellness
# 15          16         Baby Products
# 16          17         Organic Foods
# 17          18        Beverage Mixes
# 18          19   International Foods
# 19          20          Canned Goods
# 20          21    Ready-to-Eat Meals
# 21          22  Gluten-Free Products
#
#                                           DESCRIPTION
# 0        Soft drinks, coffees, teas, beers, and ales.
# 1   Sweet and savory sauces, relishes, spreads, an...
# 2                Desserts, candies, and sweet breads.
# 3                   Cheeses and other dairy products.
# 4                Breads, crackers, pasta, and cereal.
# 5                                     Prepared meats.
# 6                          Dried fruit and bean curd.
# 7                                   Seaweed and fish.
# 8              Chips, popcorn, and other snack foods.
# 9             Frozen meals, vegetables, and desserts.
# 10                  Flours, sugars, and baking mixes.
# 11  Shampoos, soaps, and other personal care produ...
# 12  Cleaning supplies, paper products, and laundry...
# 13                     Food and accessories for pets.
# 14        Vitamins, supplements, and health products.
# 15         Diapers, baby food, and infant care items.
# 16               Foods made with organic ingredients.
# 17                   Powdered and liquid drink mixes.
# 18           Specialty foods from different cuisines.
# 19              Canned vegetables, fruits, and soups.
# 20          Pre-packaged meals that are ready to eat.
# 21             Foods suitable for a gluten-free diet.
